# %% [markdown]
# # Patient Analysis
#
# This script analysis certain information about the patients.

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import io as sio
from scipy import signal as sps
from scipy import linalg as spl
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join as osj

import pickle
import wfdb

# %% [markdown]
# ## Get patient infos

# %%
ROOT = osj("..", "physionet.org/files/mitdb/1.0.0")
RECORDS = osj(ROOT, "RECORDS")

# %%
def get_ecg_info(patient_ids):
    """
    The MIT-BIH data additionally contains ecg info, providing additional information, such as the age, sex, gender, and comments.
    """
    info = {}
    for id_ in patient_ids:
        _, info_ = wfdb.io.rdsamp(osj(ROOT, str(id_)))
        info[id_] = info_["comments"]
    return info

# %%
patient_ids = pd.read_csv(osj("..", "files", "patient_ids.csv"), header=None).to_numpy().reshape(-1)
ecg_info = get_ecg_info(patient_ids)

# %%
ecg_info
# Out:
# {100: ['69 M 1085 1629 x1', 'Aldomet, Inderal'],
#  101: ['75 F 1011 654 x1', 'Diapres'],
#  102: ['84 F 1525 167 x1',
#   'Digoxin',
#   'The rhythm is paced with a demand pacemaker.  The PVCs are multiform.'],
#  103: ['-1 M 742 654 x1', 'Diapres, Xyloprim'],
#  104: ['66 F 1567 694 x1',
#   'Digoxin, Pronestyl',
#   'The rate of paced rhythm is close to that of the underlying sinus rhythm,',
#   'resulting in many pacemaker fusion beats.  The PVCs are multiform.  Several',
#   'bursts of muscle noise occur, but the signals are generally of good quality.'],
#  105: ['73 F 1624 1629 x1',
#   'Digoxin, Nitropaste, Pronestyl',
#   'The PVCs are uniform.  The predominant feature of this tape is',
#   'high-grade noise and artifact.'],
#  106: ['24 F 1581 654 x1', 'Inderal', 'The PVCs are multiform.'],
#  107: ['63 M 1340 167 x1',
#   'Digoxin',
#   'Complete heart block is present. The PVCs are multiform.'],
#  108: ['87 F 1227 654 x1',
#   'Digoxin, Quinaglute',
#   'There is borderline first degree AV block and sinus arrhythmia.  The',
#   'PVCs are multiform.  The lower channel exhibits considerable noise and',
#   'baseline shifts.'],
#  109: ['64 M 1508 694 x1',
#   'Quinidine',
#   'There is first degree AV block.  The PVCs are multiform.'],
#  111: ['47 F 937 167 x1',
#   'Digoxin, Lasix',
#   'There is first degree AV block.  There are short bursts of both baseline',
#   'shifts and muscle noise, but in general, the quality is excellent.'],
#  112: ['54 M 903 654 x2',
#   'Digoxin, Pronestyl',
#   'There is S-T segment depression in the upper channel.'],
#  113: ['24 F 1240 2851 x1',
#   'None',
#   'The variation in the rate of normal sinus rhythm is possibly due to a',
#   'wandering atrial pacemaker.'],
#  114: ['72 F 750 1629 x1', 'Digoxin', 'The PVCs are uniform.'],
#  115: ['39 F 994 167 x2', 'None'],
#  116: ['68 M 1453 1629 x2', 'None', 'There are two PVC forms.'],
#  117: ['69 M 950 654 x2', 'None'],
#  118: ['69 M 1456 653 x2', 'Digoxin, Norpace', 'The PVCs are multiform.'],
#  119: ['51 F 1129 654 x2', 'Pronestyl', 'The PVCs are uniform.'],
#  121: ['83 F 1245 167 x2', 'Digoxin, Isordil, Nitropaste'],
#  122: ['51 M 640 654 x2',
#   'Digoxin, Lasix, Pronestyl',
#   'The lower channel has low-amplitude high-frequency noise throughout.'],
#  123: ['63 F 1482 694 x2',
#   'Digoxin, Inderal',
#   'The PVCs are uniform and interpolated.'],
#  124: ['77 M 1199 653 x2',
#   'Digoxin, Isordil, Quinidine',
#   'The PVCs are multiform.  The junctional escape beats follow PVCs.'],
#  200: ['64 M 1953 3655 x1',
#   'Digoxin, Quinidine',
#   'The PVCs are multiform.  There are occasional bursts of high-frequency',
#   'noise in the upper channel, and severe noise and artifact in the lower',
#   'channel.'],
#  201: ['68 M 1960 2851 x1',
#   'Digoxin, Hydrochlorthiazide, Inderal, KCl',
#   'The PVCs are uniform and late-cycle.  Junctional escape beats occur following',
#   'episodes of ventricular trigeminy.'],
#  202: ['68 M 1960 2851 x1',
#   'Digoxin, Hydrochlorthiazide, Inderal, KCl',
#   'The PVCs are uniform and late-cycle.  This record was taken from the same',
#   'analog tape as record 201.'],
#  203: ['43 M 1878 356 x1',
#   'Coumadin, Digoxin, Heparin, Hygroton, Lasix',
#   'The PVCs are multiform.  There are QRS morphology changes in the upper',
#   'channel due to axis shifts.  There is considerable noise in both channels,',
#   'including muscle artifact and baseline shifts.  This is a very difficult',
#   'record, even for humans!'],
#  205: ['59 M 1957 694 x2',
#   'Digoxin, Quinaglute',
#   'The PVCs are of two forms, one of which is much more common than the other.'],
#  207: ['89 F 859 694 x1',
#   'Digoxin, Quinaglute',
#   'This is an extremely difficult record.  The predominant rhythm is normal',
#   'sinus with first degree AV block and left bundle branch block.  There are',
#   'periods when the conduction block changes to a right bundle branch block',
#   'pattern.  The PVCs are multiform.  Idioventricular rhythm appears following',
#   'the longest episode of ventricular flutter.  The record ends during the',
#   'episode of SVTA.'],
#  208: ['23 F 2546 N/A x1',
#   'None',
#   'The PVCs are uniform.  The couplets, many of which include a fusion PVC, are',
#   'often seen in a bigeminal pattern.   The triplets each consist of two',
#   'PVCs and a fusion PVC.'],
#  209: ['62 M 1202 654 x1', 'Aldomet, Hydrodiuril, Inderal'],
#  210: ['89 M 2461 694 x1', 'None', 'The PVCs are multiform.'],
#  212: ['32 F 2879 171 x1',
#   'None',
#   'There is rate-related right bundle branch block which appears when the heart',
#   'rate exceeds approximately 90 bpm.'],
#  213: ['61 M 2817 1629 x1',
#   'Digoxin',
#   'The PVCs are multiform and usually late-cycle, frequently resulting in',
#   'fusion PVCs.  The morphology of the fusion PVCs varies from almost normal',
#   'to almost identical to that of the PVCs.'],
#  214: ['53 M 3189 1629 x1',
#   'Digoxin, Dilantin',
#   'The PVCs are multiform.  There are two episodes of artifactual amplitude',
#   'decrease and one occurrence of tape slippage.'],
#  215: ['81 M 2633 694 x1',
#   'None',
#   'The PVCs are multiform.  There are two very short occurrences of tape slippage',
#   '(each less than one second in duration).'],
#  217: ['65 M 2450 653 x1',
#   'Digoxin, Lasix, Quinidine',
#   'The PVCs are multiform.'],
#  219: ['-1 M 978 654 x1',
#   'Digoxin',
#   'Following some conversions from atrial fibrillation to normal sinus',
#   'rhythm are pauses up to 3 seconds in duration.  The PVCs are multiform.'],
#  220: ['87 F 1543 654 x2', 'Digoxin'],
#  221: ['83 M 1268 694 x1',
#   'Hydrochlorthiazide, Lasix',
#   'The PVCs are multiform, but one form is much more common than the others.'],
#  222: ['84 F 1633 1629 x1',
#   'Digoxin, Quinidine',
#   'The episodes of paroxysmal atrial flutter/fibrillation are usually',
#   'followed by nodal escape beats.  There are several intervals of',
#   'high-frequency noise/artifact in both channels.'],
#  223: ['73 M 3070 654 x2',
#   'None',
#   'The PVCs are multiform.  The two longest episodes of ventricular tachycardia',
#   'are slow (100 to 105 bpm) and bidirectional.'],
#  228: ['80 F 2775 1629 x1',
#   'Digoxin, Norpace',
#   'There is first degree AV block.  The PVCs are multiform.  There are',
#   'three short occurrences of tape slippage with a maximum duration of 2.2',
#   'seconds.'],
#  230: ['32 M 2992 3655 x2', 'Dilantin'],
#  231: ['72 F 2009 2851 x2',
#   'None',
#   'AV conduction is quite abnormal with periods of 2:1 AV block, examples',
#   'of Mobitz II block, and right bundle branch block which appears to be',
#   'rate-related.  The couplet is probably ventricular.'],
#  232: ['76 F 2777 3655 x2',
#   'Aldomet, Inderal',
#   'The rhythm is compatible with sick sinus syndrome.  There is underlying',
#   'sinus bradycardia, first degree AV block, and frequent ectopic atrial runs',
#   'at rates of 80 to 90 bpm.  There are numerous long pauses up to 6 seconds',
#   'in duration.'],
#  233: ['57 M 1682 654 x2', 'Dilantin', 'The PVCs are multiform.'],
#  234: ['56 F 1971 3655 x2', 'None', 'The PVCs are uniform.']}

# %%
dict_patient_info = {}

for patient_id, entries in ecg_info.items():

    # Get age and gender
    first_entry = [part.strip() for part in entries[0].split(' ')]
    age = int(first_entry[0])
    gender = first_entry[1]

    # Get medication
    medication_raw = entries[1]
    medication = [med.strip() for med in medication_raw.split(',')]

    # Get comments
    comments = entries[2:] if len(entries) > 2 else []
    comment_string = " ".join(comments)

    # Store in new dictionary
    dict_patient_info[patient_id] = {
        "age": age,
        "gender": gender,
        "medication": medication,
        "comment": comment_string
    }

# %%
dict_patient_info
# Out:
# {100: {'age': 69,
#   'gender': 'M',
#   'medication': ['Aldomet', 'Inderal'],
#   'comment': ''},
#  101: {'age': 75, 'gender': 'F', 'medication': ['Diapres'], 'comment': ''},
#  102: {'age': 84,
#   'gender': 'F',
#   'medication': ['Digoxin'],
#   'comment': 'The rhythm is paced with a demand pacemaker.  The PVCs are multiform.'},
#  103: {'age': -1,
#   'gender': 'M',
#   'medication': ['Diapres', 'Xyloprim'],
#   'comment': ''},
#  104: {'age': 66,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Pronestyl'],
#   'comment': 'The rate of paced rhythm is close to that of the underlying sinus rhythm, resulting in many pacemaker fusion beats.  The PVCs are multiform.  Several bursts of muscle noise occur, but the signals are generally of good quality.'},
#  105: {'age': 73,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Nitropaste', 'Pronestyl'],
#   'comment': 'The PVCs are uniform.  The predominant feature of this tape is high-grade noise and artifact.'},
#  106: {'age': 24,
#   'gender': 'F',
#   'medication': ['Inderal'],
#   'comment': 'The PVCs are multiform.'},
#  107: {'age': 63,
#   'gender': 'M',
#   'medication': ['Digoxin'],
#   'comment': 'Complete heart block is present. The PVCs are multiform.'},
#  108: {'age': 87,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Quinaglute'],
#   'comment': 'There is borderline first degree AV block and sinus arrhythmia.  The PVCs are multiform.  The lower channel exhibits considerable noise and baseline shifts.'},
#  109: {'age': 64,
#   'gender': 'M',
#   'medication': ['Quinidine'],
#   'comment': 'There is first degree AV block.  The PVCs are multiform.'},
#  111: {'age': 47,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Lasix'],
#   'comment': 'There is first degree AV block.  There are short bursts of both baseline shifts and muscle noise, but in general, the quality is excellent.'},
#  112: {'age': 54,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Pronestyl'],
#   'comment': 'There is S-T segment depression in the upper channel.'},
#  113: {'age': 24,
#   'gender': 'F',
#   'medication': ['None'],
#   'comment': 'The variation in the rate of normal sinus rhythm is possibly due to a wandering atrial pacemaker.'},
#  114: {'age': 72,
#   'gender': 'F',
#   'medication': ['Digoxin'],
#   'comment': 'The PVCs are uniform.'},
#  115: {'age': 39, 'gender': 'F', 'medication': ['None'], 'comment': ''},
#  116: {'age': 68,
#   'gender': 'M',
#   'medication': ['None'],
#   'comment': 'There are two PVC forms.'},
#  117: {'age': 69, 'gender': 'M', 'medication': ['None'], 'comment': ''},
#  118: {'age': 69,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Norpace'],
#   'comment': 'The PVCs are multiform.'},
#  119: {'age': 51,
#   'gender': 'F',
#   'medication': ['Pronestyl'],
#   'comment': 'The PVCs are uniform.'},
#  121: {'age': 83,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Isordil', 'Nitropaste'],
#   'comment': ''},
#  122: {'age': 51,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Lasix', 'Pronestyl'],
#   'comment': 'The lower channel has low-amplitude high-frequency noise throughout.'},
#  123: {'age': 63,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Inderal'],
#   'comment': 'The PVCs are uniform and interpolated.'},
#  124: {'age': 77,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Isordil', 'Quinidine'],
#   'comment': 'The PVCs are multiform.  The junctional escape beats follow PVCs.'},
#  200: {'age': 64,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Quinidine'],
#   'comment': 'The PVCs are multiform.  There are occasional bursts of high-frequency noise in the upper channel, and severe noise and artifact in the lower channel.'},
#  201: {'age': 68,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Hydrochlorthiazide', 'Inderal', 'KCl'],
#   'comment': 'The PVCs are uniform and late-cycle.  Junctional escape beats occur following episodes of ventricular trigeminy.'},
#  202: {'age': 68,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Hydrochlorthiazide', 'Inderal', 'KCl'],
#   'comment': 'The PVCs are uniform and late-cycle.  This record was taken from the same analog tape as record 201.'},
#  203: {'age': 43,
#   'gender': 'M',
#   'medication': ['Coumadin', 'Digoxin', 'Heparin', 'Hygroton', 'Lasix'],
#   'comment': 'The PVCs are multiform.  There are QRS morphology changes in the upper channel due to axis shifts.  There is considerable noise in both channels, including muscle artifact and baseline shifts.  This is a very difficult record, even for humans!'},
#  205: {'age': 59,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Quinaglute'],
#   'comment': 'The PVCs are of two forms, one of which is much more common than the other.'},
#  207: {'age': 89,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Quinaglute'],
#   'comment': 'This is an extremely difficult record.  The predominant rhythm is normal sinus with first degree AV block and left bundle branch block.  There are periods when the conduction block changes to a right bundle branch block pattern.  The PVCs are multiform.  Idioventricular rhythm appears following the longest episode of ventricular flutter.  The record ends during the episode of SVTA.'},
#  208: {'age': 23,
#   'gender': 'F',
#   'medication': ['None'],
#   'comment': 'The PVCs are uniform.  The couplets, many of which include a fusion PVC, are often seen in a bigeminal pattern.   The triplets each consist of two PVCs and a fusion PVC.'},
#  209: {'age': 62,
#   'gender': 'M',
#   'medication': ['Aldomet', 'Hydrodiuril', 'Inderal'],
#   'comment': ''},
#  210: {'age': 89,
#   'gender': 'M',
#   'medication': ['None'],
#   'comment': 'The PVCs are multiform.'},
#  212: {'age': 32,
#   'gender': 'F',
#   'medication': ['None'],
#   'comment': 'There is rate-related right bundle branch block which appears when the heart rate exceeds approximately 90 bpm.'},
#  213: {'age': 61,
#   'gender': 'M',
#   'medication': ['Digoxin'],
#   'comment': 'The PVCs are multiform and usually late-cycle, frequently resulting in fusion PVCs.  The morphology of the fusion PVCs varies from almost normal to almost identical to that of the PVCs.'},
#  214: {'age': 53,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Dilantin'],
#   'comment': 'The PVCs are multiform.  There are two episodes of artifactual amplitude decrease and one occurrence of tape slippage.'},
#  215: {'age': 81,
#   'gender': 'M',
#   'medication': ['None'],
#   'comment': 'The PVCs are multiform.  There are two very short occurrences of tape slippage (each less than one second in duration).'},
#  217: {'age': 65,
#   'gender': 'M',
#   'medication': ['Digoxin', 'Lasix', 'Quinidine'],
#   'comment': 'The PVCs are multiform.'},
#  219: {'age': -1,
#   'gender': 'M',
#   'medication': ['Digoxin'],
#   'comment': 'Following some conversions from atrial fibrillation to normal sinus rhythm are pauses up to 3 seconds in duration.  The PVCs are multiform.'},
#  220: {'age': 87, 'gender': 'F', 'medication': ['Digoxin'], 'comment': ''},
#  221: {'age': 83,
#   'gender': 'M',
#   'medication': ['Hydrochlorthiazide', 'Lasix'],
#   'comment': 'The PVCs are multiform, but one form is much more common than the others.'},
#  222: {'age': 84,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Quinidine'],
#   'comment': 'The episodes of paroxysmal atrial flutter/fibrillation are usually followed by nodal escape beats.  There are several intervals of high-frequency noise/artifact in both channels.'},
#  223: {'age': 73,
#   'gender': 'M',
#   'medication': ['None'],
#   'comment': 'The PVCs are multiform.  The two longest episodes of ventricular tachycardia are slow (100 to 105 bpm) and bidirectional.'},
#  228: {'age': 80,
#   'gender': 'F',
#   'medication': ['Digoxin', 'Norpace'],
#   'comment': 'There is first degree AV block.  The PVCs are multiform.  There are three short occurrences of tape slippage with a maximum duration of 2.2 seconds.'},
#  230: {'age': 32, 'gender': 'M', 'medication': ['Dilantin'], 'comment': ''},
#  231: {'age': 72,
#   'gender': 'F',
#   'medication': ['None'],
#   'comment': 'AV conduction is quite abnormal with periods of 2:1 AV block, examples of Mobitz II block, and right bundle branch block which appears to be rate-related.  The couplet is probably ventricular.'},
#  232: {'age': 76,
#   'gender': 'F',
#   'medication': ['Aldomet', 'Inderal'],
#   'comment': 'The rhythm is compatible with sick sinus syndrome.  There is underlying sinus bradycardia, first degree AV block, and frequent ectopic atrial runs at rates of 80 to 90 bpm.  There are numerous long pauses up to 6 seconds in duration.'},
#  233: {'age': 57,
#   'gender': 'M',
#   'medication': ['Dilantin'],
#   'comment': 'The PVCs are multiform.'},
#  234: {'age': 56,
#   'gender': 'F',
#   'medication': ['None'],
#   'comment': 'The PVCs are uniform.'}}

# %%
def save_patient_infos(dict_patient_info):
    with open(osj("..", "files", "patient_infos.pkl"), "wb") as f:
        pickle.dump(dict_patient_info, f)

# %%
# save_patient_infos(dict_patient_info)

# %% [markdown]
# ## Get patient files

# %%
patient_ids = pd.read_csv(osj("..", "files", "patient_ids.csv"), header=None).to_numpy().reshape(-1)

valid_patients = pd.read_csv(osj("..", "files", "valid_patients.csv"), header=None).to_numpy().reshape(-1)
paced_patients = pd.read_csv(osj("..", "files", "paced_patients.csv"), header=None).to_numpy().reshape(-1)
excluded_patients = pd.read_csv(osj("..", "files", "excluded_patients.csv"), header=None).to_numpy().reshape(-1)
class_counts = pd.read_csv(osj("..", "files", "patient_beat_class_counts.csv"), header=None).to_numpy().reshape(-1)

patient_infos = pickle.load(open(osj("..", "files", "patient_infos.pkl"), "rb"))

# %%
len(patient_ids), len(paced_patients), len(excluded_patients), len(valid_patients)
# Out:
# (48, 4, 10, 34)

# %%
valid_patients
# Out:
# array([100, 101, 103, 106, 108, 109, 111, 112, 113, 115, 116, 117, 118,
#        119, 121, 122, 123, 124, 200, 203, 205, 208, 210, 212, 214, 215,
#        219, 220, 221, 228, 230, 231, 232, 233])

# %% [markdown]
# ## Get class statistics

# %%
columns   = class_counts[:3]
data_only = class_counts[3:]

triplets = [data_only[i:i+3] for i in range(0, len(data_only), 3)]
df_class_counts = pd.DataFrame(triplets, columns=columns)

df_class_counts["patient_id"] = df_class_counts["patient_id"].astype(int)
df_class_counts["num_healthy"] = df_class_counts["num_healthy"].astype(int)
df_class_counts["num_arrhythmia"] = df_class_counts["num_arrhythmia"].astype(int)

df_class_counts
# Out:
#     patient_id  num_healthy  num_arrhythmia
# 0          100         1870              34
# 1          101         1511               5
# 2          102            0               4
# 3          103         1725               2
# 4          104            0              19
# 5          105         2112              46
# 6          106         1222             520
# 7          107            0              57
# 8          108         1449              23
# 9          109         2065              40
# 10         111         1769               1
# 11         112         2107               2
# 12         113         1499               6
# 13         114         1557              59
# 14         115         1635               0
# 15         116         1916             110
# 16         117         1281               1
# 17         118         1810             112
# 18         119         1279             444
# 19         121         1554               2
# 20         122         2052               0
# 21         123         1264               3
# 22         124         1297              83
# 23         200         1416             857
# 24         201         1193             328
# 25         202         1798              75
# 26         203         2098             451
# 27         205         2122              85
# 28         207         1214             316
# 29         208         1298            1368
# 30         209         2140             384
# 31         210         2004             227
# 32         212         2283               0
# 33         213         2206             610
# 34         214         1652             259
# 35         215         2651             168
# 36         217            7             160
# 37         219         1711              72
# 38         220         1599              94
# 39         221         1701             396
# 40         222         1901             209
# 41         223         1664             560
# 42         228         1365             365
# 43         230         1823               1
# 44         231         1241               3
# 45         232          315            1381
# 46         233         1844             848
# 47         234         2236              53

# %%
valid_class_counts = df_class_counts[df_class_counts["patient_id"].isin(valid_patients)]

# get sum of arrhythmia and healthy beats
total_healthy = valid_class_counts["num_healthy"].sum()
total_arrhythmia = valid_class_counts["num_arrhythmia"].sum()

# get percentage of arrhythmia and healthy beats
total = total_healthy + total_arrhythmia
perc_healthy = total_healthy / total * 100
perc_arrhythmia = total_arrhythmia / total * 100

print(f"Total number of valid beats: {total}")
print(f"Sum of healthy beats: {total_healthy} ({perc_healthy:.2f}%)")
print(f"Sum of arrhythmic beats: {total_arrhythmia} ({perc_arrhythmia:.2f}%)")
# Out:
# Total number of valid beats: 64391
# Sum of healthy beats: 56428 (87.63%)
# Sum of arrhythmic beats: 7963 (12.37%)
